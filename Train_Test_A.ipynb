# %%
from numpy.random import seed
import pandas as pd
seed(1)
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv("Data/Netflix_tweets.csv")

data.head()
# Out:
#     timestamp  likes  retweets  \
# 0  2018-12-24      0         0
# 1  2018-12-24      0         0
# 2  2018-12-24      1         0
# 3  2018-12-24      1         0
# 4  2018-12-24      1         1
#
#                                                 text
# 0  Kaya Scodelario To Star In Netflix’s Figure Sk...
# 1               I need somebody Netflix password lol
# 2  Can we talk about how @KevinSpacey just hid be...
# 3  an ideal date would be eating takeout dinner i...
# 4  Thank you Mr. President for staying home and t...

# %%
X = sklearn.data('likes')
y = sklearn.datasets.make_circles(noise=0.05, factor=.2, random_state=1)

# %%
# Create Data
X, y = sklearn.data(noise=0.05, factor=.2, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-3e88a0f2e377> in <module>
#       1 # Create Data
# ----> 2 X, y = sklearn.data(noise=0.05, factor=.2, random_state=1)
#       3 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#
# AttributeError: module 'sklearn' has no attribute 'data'

# %%
# Create a StandardScater model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
deep_model = Sequential()
deep_model.add(Dense(units=6, activation='relu', input_dim=2))
deep_model.add(Dense(units=6, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 18
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 14
# =================================================================
# Total params: 32
# Trainable params: 32
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 75 samples
# Epoch 1/100
# 75/75 - 0s - loss: 0.7233 - accuracy: 0.5200
# Epoch 2/100
# 75/75 - 0s - loss: 0.7207 - accuracy: 0.5200
# Epoch 3/100
# 75/75 - 0s - loss: 0.7182 - accuracy: 0.5333
# Epoch 4/100
# 75/75 - 0s - loss: 0.7158 - accuracy: 0.5600
# Epoch 5/100
# 75/75 - 0s - loss: 0.7134 - accuracy: 0.5200
# Epoch 6/100
# 75/75 - 0s - loss: 0.7113 - accuracy: 0.4933
# Epoch 7/100
# 75/75 - 0s - loss: 0.7093 - accuracy: 0.4800
# Epoch 8/100
# 75/75 - 0s - loss: 0.7074 - accuracy: 0.4800
# Epoch 9/100
# 75/75 - 0s - loss: 0.7054 - accuracy: 0.4667
# Epoch 10/100
# 75/75 - 0s - loss: 0.7039 - accuracy: 0.4667
# Epoch 11/100
# 75/75 - 0s - loss: 0.7016 - accuracy: 0.4400
# Epoch 12/100
# 75/75 - 0s - loss: 0.6997 - accuracy: 0.4267
# Epoch 13/100
# 75/75 - 0s - loss: 0.6982 - accuracy: 0.3867
# Epoch 14/100
# 75/75 - 0s - loss: 0.6962 - accuracy: 0.3600
# Epoch 15/100
# 75/75 - 0s - loss: 0.6944 - accuracy: 0.3333
# Epoch 16/100
# 75/75 - 0s - loss: 0.6928 - accuracy: 0.3467
# Epoch 17/100
# 75/75 - 0s - loss: 0.6911 - accuracy: 0.3333
# Epoch 18/100
# 75/75 - 0s - loss: 0.6895 - accuracy: 0.3333
# Epoch 19/100
# 75/75 - 0s - loss: 0.6878 - accuracy: 0.3333
# Epoch 20/100
# 75/75 - 0s - loss: 0.6860 - accuracy: 0.3333
# Epoch 21/100
# 75/75 - 0s - loss: 0.6843 - accuracy: 0.3333
# Epoch 22/100
# 75/75 - 0s - loss: 0.6824 - accuracy: 0.3600
# Epoch 23/100
# 75/75 - 0s - loss: 0.6805 - accuracy: 0.3733
# Epoch 24/100
# 75/75 - 0s - loss: 0.6787 - accuracy: 0.4000
# Epoch 25/100
# 75/75 - 0s - loss: 0.6768 - accuracy: 0.4133
# Epoch 26/100
# 75/75 - 0s - loss: 0.6750 - accuracy: 0.4133
# Epoch 27/100
# 75/75 - 0s - loss: 0.6734 - accuracy: 0.4133
# Epoch 28/100
# 75/75 - 0s - loss: 0.6716 - accuracy: 0.4267
# Epoch 29/100
# 75/75 - 0s - loss: 0.6700 - accuracy: 0.4267
# Epoch 30/100
# 75/75 - 0s - loss: 0.6684 - accuracy: 0.4267
# Epoch 31/100
# 75/75 - 0s - loss: 0.6666 - accuracy: 0.4400
# Epoch 32/100
# 75/75 - 0s - loss: 0.6650 - accuracy: 0.4400
# Epoch 33/100
# 75/75 - 0s - loss: 0.6634 - accuracy: 0.4400
# Epoch 34/100
# 75/75 - 0s - loss: 0.6618 - accuracy: 0.4533
# Epoch 35/100
# 75/75 - 0s - loss: 0.6603 - accuracy: 0.4533
# Epoch 36/100
# 75/75 - 0s - loss: 0.6585 - accuracy: 0.4533
# Epoch 37/100
# 75/75 - 0s - loss: 0.6569 - accuracy: 0.4667
# Epoch 38/100
# 75/75 - 0s - loss: 0.6552 - accuracy: 0.4667
# Epoch 39/100
# 75/75 - 0s - loss: 0.6537 - accuracy: 0.4667
# Epoch 40/100
# 75/75 - 0s - loss: 0.6520 - accuracy: 0.4667
# Epoch 41/100
# 75/75 - 0s - loss: 0.6503 - accuracy: 0.4667
# Epoch 42/100
# 75/75 - 0s - loss: 0.6488 - accuracy: 0.4667
# Epoch 43/100
# 75/75 - 0s - loss: 0.6472 - accuracy: 0.4667
# Epoch 44/100
# 75/75 - 0s - loss: 0.6454 - accuracy: 0.4667
# Epoch 45/100
# 75/75 - 0s - loss: 0.6439 - accuracy: 0.4667
# Epoch 46/100
# 75/75 - 0s - loss: 0.6424 - accuracy: 0.4667
# Epoch 47/100
# 75/75 - 0s - loss: 0.6407 - accuracy: 0.4667
# Epoch 48/100
# 75/75 - 0s - loss: 0.6393 - accuracy: 0.4667
# Epoch 49/100
# 75/75 - 0s - loss: 0.6377 - accuracy: 0.4667
# Epoch 50/100
# 75/75 - 0s - loss: 0.6362 - accuracy: 0.4667
# Epoch 51/100
# 75/75 - 0s - loss: 0.6346 - accuracy: 0.4667
# Epoch 52/100
# 75/75 - 0s - loss: 0.6330 - accuracy: 0.4667
# Epoch 53/100
# 75/75 - 0s - loss: 0.6315 - accuracy: 0.4667
# Epoch 54/100
# 75/75 - 0s - loss: 0.6299 - accuracy: 0.4800
# Epoch 55/100
# 75/75 - 0s - loss: 0.6284 - accuracy: 0.3867
# Epoch 56/100
# 75/75 - 0s - loss: 0.6269 - accuracy: 0.5733
# Epoch 57/100
# 75/75 - 0s - loss: 0.6253 - accuracy: 0.5733
# Epoch 58/100
# 75/75 - 0s - loss: 0.6238 - accuracy: 0.5867
# Epoch 59/100
# 75/75 - 0s - loss: 0.6221 - accuracy: 0.5867
# Epoch 60/100
# 75/75 - 0s - loss: 0.6207 - accuracy: 0.5867
# Epoch 61/100
# 75/75 - 0s - loss: 0.6190 - accuracy: 0.5867
# Epoch 62/100
# 75/75 - 0s - loss: 0.6174 - accuracy: 0.6000
# Epoch 63/100
# 75/75 - 0s - loss: 0.6158 - accuracy: 0.6133
# Epoch 64/100
# 75/75 - 0s - loss: 0.6142 - accuracy: 0.6133
# Epoch 65/100
# 75/75 - 0s - loss: 0.6126 - accuracy: 0.6133
# Epoch 66/100
# 75/75 - 0s - loss: 0.6110 - accuracy: 0.6133
# Epoch 67/100
# 75/75 - 0s - loss: 0.6094 - accuracy: 0.6133
# Epoch 68/100
# 75/75 - 0s - loss: 0.6079 - accuracy: 0.6133
# Epoch 69/100
# 75/75 - 0s - loss: 0.6061 - accuracy: 0.6133
# Epoch 70/100
# 75/75 - 0s - loss: 0.6044 - accuracy: 0.6133
# Epoch 71/100
# 75/75 - 0s - loss: 0.6027 - accuracy: 0.6267
# Epoch 72/100
# 75/75 - 0s - loss: 0.6010 - accuracy: 0.6533
# Epoch 73/100
# 75/75 - 0s - loss: 0.5992 - accuracy: 0.6533
# Epoch 74/100
# 75/75 - 0s - loss: 0.5974 - accuracy: 0.6533
# Epoch 75/100
# 75/75 - 0s - loss: 0.5956 - accuracy: 0.6533
# Epoch 76/100
# 75/75 - 0s - loss: 0.5936 - accuracy: 0.6533
# Epoch 77/100
# 75/75 - 0s - loss: 0.5917 - accuracy: 0.6533
# Epoch 78/100
# 75/75 - 0s - loss: 0.5898 - accuracy: 0.6667
# Epoch 79/100
# 75/75 - 0s - loss: 0.5880 - accuracy: 0.6800
# Epoch 80/100
# 75/75 - 0s - loss: 0.5860 - accuracy: 0.6800
# Epoch 81/100
# 75/75 - 0s - loss: 0.5840 - accuracy: 0.6667
# Epoch 82/100
# 75/75 - 0s - loss: 0.5821 - accuracy: 0.6667
# Epoch 83/100
# 75/75 - 0s - loss: 0.5801 - accuracy: 0.6667
# Epoch 84/100
# 75/75 - 0s - loss: 0.5783 - accuracy: 0.6800
# Epoch 85/100
# 75/75 - 0s - loss: 0.5765 - accuracy: 0.6800
# Epoch 86/100
# 75/75 - 0s - loss: 0.5746 - accuracy: 0.6800
# Epoch 87/100
# 75/75 - 0s - loss: 0.5728 - accuracy: 0.6800
# Epoch 88/100
# 75/75 - 0s - loss: 0.5709 - accuracy: 0.6800
# Epoch 89/100
# 75/75 - 0s - loss: 0.5692 - accuracy: 0.6800
# Epoch 90/100
# 75/75 - 0s - loss: 0.5674 - accuracy: 0.6800
# Epoch 91/100
# 75/75 - 0s - loss: 0.5658 - accuracy: 0.6933
# Epoch 92/100
# 75/75 - 0s - loss: 0.5641 - accuracy: 0.7067
# Epoch 93/100
# 75/75 - 0s - loss: 0.5625 - accuracy: 0.7200
# Epoch 94/100
# 75/75 - 0s - loss: 0.5610 - accuracy: 0.7200
# Epoch 95/100
# 75/75 - 0s - loss: 0.5594 - accuracy: 0.7200
# Epoch 96/100
# 75/75 - 0s - loss: 0.5580 - accuracy: 0.7200
# Epoch 97/100
# 75/75 - 0s - loss: 0.5564 - accuracy: 0.7200
# Epoch 98/100
# 75/75 - 0s - loss: 0.5550 - accuracy: 0.7200
# Epoch 99/100
# 75/75 - 0s - loss: 0.5536 - accuracy: 0.7200
# Epoch 100/100
# 75/75 - 0s - loss: 0.5522 - accuracy: 0.7067

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
