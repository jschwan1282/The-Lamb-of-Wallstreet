# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv('cleanedtweets.csv', encoding='utf-8')
stock = pd.read_csv('NTFLX.csv', encoding='utf-8')

# %%
stock.dtypes
stock.head()
# Out:
#          Date    Open    High      Low   Close   Volume
# 0   11/1/2019  288.70  289.12  283.020  286.81  5594293
# 1  10/31/2019  291.00  291.45  284.780  287.41  5090021
# 2  10/30/2019  284.34  293.49  283.000  291.45  9345562
# 3  10/29/2019  281.87  284.41  277.545  281.21  4356181
# 4  10/28/2019  278.05  285.75  277.350  281.86  6248433

# %%
stock_close = stock[['Date', ' Close']]
stock_close.head()
# Out:
#          Date   Close
# 0   11/1/2019  286.81
# 1  10/31/2019  287.41
# 2  10/30/2019  291.45
# 3  10/29/2019  281.21
# 4  10/28/2019  281.86

# %%
df['Date'] = pd.to_datetime(df['timestamp']).dt.strftime('%m/%d/%Y')
stock['Date'] = pd.to_datetime(stock['Date']).dt.date
stock_close.head()
# Out:
#          Date   Close
# 0   11/1/2019  286.81
# 1  10/31/2019  287.41
# 2  10/30/2019  291.45
# 3  10/29/2019  281.21
# 4  10/28/2019  281.86

# %%
df.drop('timestamp', axis=1, inplace=True)
df.head()
# Out:
#    likes  retweets                                               text  \
# 0      0         0  The one on Netflix? I watched all of it thursd...
# 1      1         0  its November 1st and Netflix covered with Chri...
# 2      3         0  Lol just before The Chilling Adventures of Sab...
# 3      0         0  Thank you, @netflix, for getting the licensing...
# 4      0         0  TFW you hear yourself ask your husband to sear...
#
#          Date
# 0  11/03/2018
# 1  11/03/2018
# 2  11/03/2018
# 3  11/03/2018
# 4  11/03/2018

# %%
merged = pd.merge(left = df, right = stock_close, how = 'right', on="Date")
merged.count
# Out:
# <bound method DataFrame.count of        likes  retweets                                               text  \
# 0        1.0       0.0  Thanks for sharing. Love this article - spot o...
# 1        0.0       0.0             Good movie!   Well acted and exciting.
# 2        0.0       0.0  Don’t Watch This on Netflix is crazy man, take...
# 3        0.0       0.0  Oh my gosh, I can't wait. Would you believe I ...
# 4        0.0       0.0                                   Ozark in Netflix
# 5        0.0       0.0  Agreed. I've always loved the book because it ...
# 6        0.0       0.0  It’s on Netflix, watch it you’ll cry, kinda li...
# 7        1.0       0.0  If I was given entirely the choice it would ha...
# 8        0.0       0.0  If you have not watched @SonsofAnarchy on @net...
# 9        0.0       0.0  Started watching Mindhunter on Netflix on my f...
# 10       0.0       0.0  The only requirements are being over 18 and ha...
# 11       0.0       0.0  FOR SALE! FOR SALE!\n\n NETFLIX PREMIUM ACCOUN...
# 12       0.0       0.0  This Daredevil episode I'm watching in my stud...
# 13       0.0       0.0  Omg yess!!! Thank you @netflix  my favorite sh...
# 14       0.0       0.0  Happy Veterans Day to all who have served and ...
# 15       0.0       0.0                        No claustrophobia in there?
# 16       2.0       0.0  I really need to get internet. Everything take...
# 17       0.0       0.0    @RobertMBall the Wailings on Netflix. Tis good.
# 18       5.0       0.0  A small group of us has decided to binge watch...
# 19       0.0       0.0                                        sur netflix
# 20       1.0       0.0  Thanks for sharing. Love this article - spot o...
# 21       0.0       0.0             Good movie!   Well acted and exciting.
# 22       0.0       0.0  Don’t Watch This on Netflix is crazy man, take...
# 23       0.0       0.0  Oh my gosh, I can't wait. Would you believe I ...
# 24       0.0       0.0                                   Ozark in Netflix
# 25       0.0       0.0  Agreed. I've always loved the book because it ...
# 26       0.0       0.0  It’s on Netflix, watch it you’ll cry, kinda li...
